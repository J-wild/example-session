# %% [markdown]
# Import the module and create a dataframe

# %%
import pandas as pd

#dataframes
mydataset = {
   "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

df = pd.DataFrame(mydataset)

# %%
print(df)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %% [markdown]
# Load a CSV File, this one lists times throught the day in 15 min increments.

# %%
df = pd.read_csv('time.csv')
print(df.to_string())
# Out:
#        12-Hour 24-Hour
# 0   12:00 a.m.   00:00
# 1   12:15 a.m.   00:15
# 2   12:30 a.m.   00:30
# 3   12:45 a.m.   00:45
# 4    1:00 a.m.   01:00
# 5    1:15 a.m.   01:15
# 6    1:30 a.m.   01:30
# 7    1:45 a.m.   01:45
# 8    2:00 a.m.   02:00
# 9    2:15 a.m.   02:15
# 10   2:30 a.m.   02:30
# 11   2:45 a.m.   02:45
# 12   3:00 a.m.   03:00
# 13   3:15 a.m.   03:15
# 14   3:30 a.m.   03:30
# 15   3:45 a.m.   03:45
# 16   4:00 a.m.   04:00
# 17   4:15 a.m.   04:15
# 18   4:30 a.m.   04:30
# 19   4:45 a.m.   04:45
# 20   5:00 a.m.   05:00
# 21   5:15 a.m.   05:15
# 22   5:30 a.m.   05:30
# 23   5:45 a.m.   05:45
# 24   6:00 a.m.   06:00
# 25   6:15 a.m.   06:15
# 26   6:30 a.m.   06:30
# 27   6:45 a.m.   06:45
# 28   7:00 a.m.   07:00
# 29   7:15 a.m.   07:15
# 30   7:30 a.m.   07:30
# 31   7:45 a.m.   07:45
# 32   8:00 a.m.   08:00
# 33   8:15 a.m.   08:15
# 34   8:30 a.m.   08:30
# 35   8:45 a.m.   08:45
# 36   9:00 a.m.   09:00
# 37   9:15 a.m.   09:15
# 38   9:30 a.m.   09:30
# ...

# %% [markdown]
# Show the info about the dataframe
